# %%
import cv2
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from preprocess import pencil_sketch

# %%
img = cv2.imread('test.png')
plt.imshow(img);

# %%
sketch = pencil_sketch('test.png', 256, 256)
plt.imshow(sketch);
